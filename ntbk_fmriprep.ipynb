# %% [markdown]
# ---

# %% [markdown]
# # FMRIPREP BBX Preprocessing

# %%
# import pacakges 

import os, glob, shutil
import ipywidgets as widgets
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import seaborn as sns
import subprocess as sp

from openpyxl import load_workbook
from IPython.display import SVG, display
from datetime import date

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_rows', 159)
#pd.set_option('display.max_colwidth', -1)
from matplotlib import rcParams
rcParams['axes.titlepad'] = 15

# %matplotlib inline

# %% [markdown]
# ## Set Variables

# %%
# Variable load and setup
date = date.today()
study_folder_path="/projects/niblab/experiments/bbx"
data_folder_path= os.path.join(study_folder_path, "data")
bids_path = os.path.join(data_folder_path, "bids/bids")
report_folder_path=os.path.join(data_folder_path, "quality_analysis")
fmriprep_path='/projects/niblab/experiments/bbx/data/fmriprep/fmriprep_trimmed-20.2.0'#'/projects/niblab/experiments/bbx/data/fmriprep/fmriprep_trimmed'

# %%
fmriprep_folders=glob.glob(os.path.join(fmriprep_path, "sub-*/ses-*"))
fmriprep_ses1=[x.split("/")[-2] for x in fmriprep_folders if 'ses-1' in x]
fmriprep_ses2=[x.split("/")[-2] for x in fmriprep_folders if 'ses-2' in x]
runs=['run-1','run-2','run-3', 'run-4']
sessions=['ses-1','ses-2']
tasks=['task-training']



remove_subs=['sub-029', 'sub-047', 'sub-049', 'sub-069', 'sub-081', 'sub-094', 'sub-101',
             'sub-105', 'sub-106', 'sub-110', 'sub-113', 'sub-122', 'sub-125', 'sub-126', 
             'sub-139', 'sub-155', 'sub-158', 'sub-165']

s2_drop_subjects=["sub-003", 'sub-012','sub-016', 'sub-018',  "sub-020", "sub-024", "sub-025",'sub-026', 'sub-035',
                  "sub-052", 'sub-056', "sub-059", "sub-060", "sub-064","sub-074", "sub-076", "sub-077", 'sub-087',
                  'sub-108', "sub-147", "sub-150", "sub-167"]

fmriprep_ses1=[x for x in fmriprep_ses1 if x not in remove_subs]
#fmriprep_ses2=[x for x in fmriprep_ses2 if x not in s2_drop_subjects]



subject_list=list(set(fmriprep_ses1))#+fmriprep_ses2))

subject_list.sort()


#remove_subs=[ 'sub-029', 'sub-047', 'sub-049', 'sub-057', 'sub-069', 'sub-081', 'sub-105', 
 #             'sub-125', 'sub-126', 'sub-158', 'sub-165']


#print(s2_drop_subjects)

bids_subs=[x.split("/")[-1] for x in glob.glob(os.path.join(data_folder_path,"bids/sub-*"))]

# %%
subject_list[:4]
# Out:
# ['sub-001', 'sub-002', 'sub-003', 'sub-004']

# %% [markdown]
# Lets compare the subject folders found for BIDS and the subjects folders found for FMRIPREP to see what subject might be missing.

# %%
bids_subs=glob.glob(os.path.join(data_folder_path, "bids/bids/sub-*"))
bids_subs=[x.split('/')[-1] for x in bids_subs if x.split('/')[-1] not in remove_subs]
prep_subs=glob.glob(os.path.join(fmriprep_path, 'sub-*'))
prep_subs=[x.split('/')[-1] for x in prep_subs if '.html' not in x]

missing=[x for x in bids_subs if x not in prep_subs]

print('[INFO] %s fmriprep subject folders found'%len(prep_subs))
print('[INFO] %s missing fmriprep subjects'%len(missing))
print('Missing Subjects >>>> %s'%missing)
# Out:
# [INFO] 152 fmriprep subject folders found
# [INFO] 0 missing fmriprep subjects
# Missing Subjects >>>> []

# %% [markdown]
# ## Submit batch
# ---

# %%
def submit_fmriprep_batch(job_file, x, submit_job=False):
    print('[INFO] batch file: %s'%job_file)
    batch_cmd='sbatch --array={}-{}%1 {}'.format(x,x,job_file)
    print('[INFO] batch command: {}'.format(batch_cmd))
    
    # submit batch job
    if submit_job==True: 
        sp.run(batch_cmd, shell=True)        
        print('[INFO] submitted job.')

# %%
print(bids_subs)
# Out:
# ['sub-001', 'sub-002', 'sub-003', 'sub-005', 'sub-006', 'sub-007', 'sub-008', 'sub-009', 'sub-010', 'sub-011', 'sub-012', 'sub-013', 'sub-014', 'sub-015', 'sub-016', 'sub-017', 'sub-018', 'sub-019', 'sub-020', 'sub-021', 'sub-022', 'sub-023', 'sub-024', 'sub-025', 'sub-026', 'sub-027', 'sub-028', 'sub-030', 'sub-031', 'sub-032', 'sub-033', 'sub-034', 'sub-035', 'sub-036', 'sub-037', 'sub-038', 'sub-039', 'sub-040', 'sub-041', 'sub-042', 'sub-043', 'sub-044', 'sub-045', 'sub-046', 'sub-048', 'sub-050', 'sub-051', 'sub-052', 'sub-053', 'sub-054', 'sub-055', 'sub-056', 'sub-057', 'sub-058', 'sub-059', 'sub-060', 'sub-061', 'sub-062', 'sub-063', 'sub-064', 'sub-065', 'sub-066', 'sub-067', 'sub-068', 'sub-070', 'sub-071', 'sub-072', 'sub-073', 'sub-074', 'sub-075', 'sub-076', 'sub-077', 'sub-078', 'sub-079', 'sub-080', 'sub-082', 'sub-083', 'sub-084', 'sub-085', 'sub-086', 'sub-087', 'sub-088', 'sub-089', 'sub-090', 'sub-091', 'sub-092', 'sub-093', 'sub-095', 'sub-096', 'sub-097', 'sub-098', 'sub-099', 'sub-100', 'sub-102', 'sub-103', 'sub-104', 'sub-107', 'sub-108', 'sub-109', 'sub-111', 'sub-112', 'sub-114', 'sub-115', 'sub-116', 'sub-117', 'sub-118', 'sub-119', 'sub-120', 'sub-121', 'sub-123', 'sub-124', 'sub-127', 'sub-128', 'sub-129', 'sub-130', 'sub-131', 'sub-132', 'sub-133', 'sub-134', 'sub-135', 'sub-136', 'sub-137', 'sub-138', 'sub-140', 'sub-141', 'sub-142', 'sub-143', 'sub-144', 'sub-145', 'sub-146', 'sub-147', 'sub-148', 'sub-149', 'sub-150', 'sub-151', 'sub-152', 'sub-153', 'sub-154', 'sub-156', 'sub-157', 'sub-159', 'sub-160', 'sub-161', 'sub-162', 'sub-163', 'sub-164', 'sub-166', 'sub-167', 'sub-168', 'sub-169', 'sub-170', 'sub-004']

# %% [markdown]
# Set variables for batch command and submit job:
# `sbatch --array={start_id}-{finish_id}%{z} {job_file}`

# %%
# Set Parameters 
fmriprep_job_file='/projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job'

submission_list=bids_subs

for sub_id in submission_list:
    num_id=sub_id.split("-")[1].lstrip('0')
    submit_job=True # set to True when you want to run the file 
    submit_fmriprep_batch(fmriprep_job_file,num_id, submit_job)
# Out:
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=1-1%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=2-2%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=3-3%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=5-5%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=6-6%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=7-7%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=8-8%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=9-9%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=10-10%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=11-11%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=12-12%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=13-13%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=14-14%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=15-15%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=16-16%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=17-17%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=18-18%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=19-19%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=20-20%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=21-21%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=22-22%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=23-23%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=24-24%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=25-25%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=26-26%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=27-27%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=28-28%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=30-30%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=31-31%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=32-32%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=33-33%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=34-34%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=35-35%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=36-36%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=37-37%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=38-38%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=39-39%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=40-40%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=41-41%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=42-42%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=43-43%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=44-44%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=45-45%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=46-46%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=48-48%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=50-50%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=51-51%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=52-52%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=53-53%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=54-54%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=55-55%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=56-56%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=57-57%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=58-58%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=59-59%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=60-60%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=61-61%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=62-62%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=63-63%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=64-64%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=65-65%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=66-66%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=67-67%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=68-68%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=70-70%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=71-71%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=72-72%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=73-73%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=74-74%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=75-75%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=76-76%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=77-77%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=78-78%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=79-79%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=80-80%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=82-82%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=83-83%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=84-84%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=85-85%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=86-86%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=87-87%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=88-88%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=89-89%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=90-90%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=91-91%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=92-92%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=93-93%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=95-95%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=96-96%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=97-97%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=98-98%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=99-99%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=100-100%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=102-102%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=103-103%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=104-104%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=107-107%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=108-108%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=109-109%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=111-111%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=112-112%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=114-114%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=115-115%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=116-116%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=117-117%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=118-118%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=119-119%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=120-120%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=121-121%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=123-123%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=124-124%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=127-127%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=128-128%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=129-129%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=130-130%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=131-131%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=132-132%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=133-133%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=134-134%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=135-135%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=136-136%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=137-137%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=138-138%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=140-140%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=141-141%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=142-142%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=143-143%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=144-144%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=145-145%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=146-146%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=147-147%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=148-148%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=149-149%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=150-150%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=151-151%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=152-152%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=153-153%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=154-154%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=156-156%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=157-157%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=159-159%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=160-160%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=161-161%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=162-162%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=163-163%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=164-164%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=166-166%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=167-167%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=168-168%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=169-169%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=170-170%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.
# [INFO] batch file: /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] batch command: sbatch --array=4-4%1 /projects/niblab/experiments/bbx/code/preprocessing/fmriprep/fmriprep_updated.job
# [INFO] submitted job.

# %% [markdown]
# ---

# %% [markdown]
# ## Quality Report
# ---

# %%
"""
# Methods
"""

def quality_report():
    
    s1_bids_subject_list=[x.split("/")[-2] for x in 
                   glob.glob(os.path.join(study_folder_path, "data/bids/bids/sub-*/ses-1"))]

    s1_bids_subject_list=[x for x in s1_bids_subject_list ]#if x not in remove_subs]

    s2_bids_subject_list=[x.split("/")[-2] for x in 
                       glob.glob(os.path.join(study_folder_path, "data/bids/bids/sub-*/ses-2"))]

    s2_bids_subject_list=[x for x in s2_bids_subject_list]  #if x not in remove_subs]

    s1_fprep_subject_list=fmriprep_ses1
    s2_fprep_subject_list=fmriprep_ses2
    
    s1_fprep_missing = [x for x in s1_bids_subject_list if x not in s1_fprep_subject_list]
    s2_fprep_missing = [x for x in s2_bids_subject_list if x not in s2_fprep_subject_list]

    fprep_missing=list(set(s1_fprep_missing + s2_fprep_missing))
    fprep_missing.sort()

    s1_fprep_subject_list.sort()
    print("[INFO] %s session 1 fmriprep subjects found. "%len(s1_fprep_subject_list))
    print("\n[INFO] %s session 1 bids subjects are not processed through fmriprep."%len(s1_fprep_missing))
    print("\n[INFO] subjects found: %s \n\n"%s1_fprep_subject_list)
    print("[INFO] subjects missing: %s "%s1_fprep_missing)
    
    """print("\n[INFO] %s session 2 fmriprep subjects found."%len(s2_fprep_subject_list))
    print("\n[INFO] %s session 2 bids subjects are not processed through fmriprep."%len(s2_fprep_missing))
    print("\n[INFO] subjects found: %s "%s2_fprep_missing)
    print("\n[INFO] subjects missing: %s"%fprep_missing)
    print("\n[INFO] %s \n\n"%s2_fprep_subject_list)
    """
    
    
    
"""
# Build FMRIPREP Report 

"""


def build_fmriprep_report(write_files=False):
    
    print('[INFO] fmriprep data path: %s '%fmriprep_path)

    sessions=['ses-1', 'ses-2']
    dataframes=[]
        
    # loop through sessions
    for session in sessions:
        #print("\n[INFO] %s"%session)
        

        data_dict={} #initialize data dictionary for session

        # loop through subject set by subject
        for i in range(1,171):
            train_ct=0
            rest_ct=0
            if session == 'ses-2':
                rl_ct=0
            subject="sub-%s"%f'{i:03}'
            bids_folder=os.path.join(fmriprep_path, subject,
                                    session)

            if subject not in data_dict:
                data_dict[subject] = {}


        
            # get anat file and save plot
            #_space-MNI152NLin2009cAsym_desc-preproc_T1w.nii.g
            anat_imgs =glob.glob(os.path.join(fmriprep_path, subject, "anat",
                   '%s_space-MNI152NLin2009cAsym_desc-preproc_T1w.nii.gz'%(subject)))

            #if os.path.exists(anat_img): 
            data_dict[subject]["anat_file_ct"]=len(anat_imgs)

            # get functional files and check their volume and plot images
            func_files=glob.glob(os.path.join(
                    fmriprep_path, subject, session,
                    "func/*task-*_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz" ))

            for func_file in func_files:
                
                task=func_file.split("/")[-1].split("_")[2]
                vol = sp.check_output(["fslnvols", func_file])
                vol=str(vol,'utf-8').strip("\n")


                if "resting" in task:
                    rest_ct+=1
                    var_name="%s_vol"%task
                    data_dict[subject][var_name]=vol
                elif "rl" in task:
                    rl_ct+=1
                    run=func_file.split("/")[-1].split("_")[3]
                    var_name="%s_%s_vol"%(task,run)
                    data_dict[subject][var_name]=vol
                elif "training" in task:
                    train_ct+=1
                    run=func_file.split("/")[-1].split("_")[3]
                    var_name="%s_%s_vol"%(task,run)
                    data_dict[subject][var_name]=vol

            if session == 'ses-2':
                data_dict[subject]["rl_file_ct"]=rl_ct
            data_dict[subject]["train_file_ct"]=train_ct
            data_dict[subject]["rest_file_ct"]=rest_ct
            # plot functionals
            #pool = Pool()
            #pool.map(plot_functionals, func_files)
            #pool.close()

        dataframe=pd.DataFrame(data_dict).T        
        dataframes.append(dataframe)
        #dataframe.to_excel(writer, sheet_name="%s_fmriprep"%session)
    #writer.save()
    #writer.close()
    return dataframes;

# %%
quality_report()
# Out:
# [INFO] 148 session 1 fmriprep subjects found.
#
# [INFO] 4 session 1 bids subjects are not processed through fmriprep.
#
# [INFO] subjects found: ['sub-001', 'sub-002', 'sub-003', 'sub-004', 'sub-005', 'sub-006', 'sub-007', 'sub-008', 'sub-009', 'sub-010', 'sub-011', 'sub-012', 'sub-013', 'sub-014', 'sub-015', 'sub-017', 'sub-018', 'sub-019', 'sub-020', 'sub-021', 'sub-022', 'sub-023', 'sub-024', 'sub-025', 'sub-026', 'sub-027', 'sub-028', 'sub-030', 'sub-031', 'sub-032', 'sub-033', 'sub-034', 'sub-035', 'sub-036', 'sub-037', 'sub-038', 'sub-039', 'sub-040', 'sub-041', 'sub-042', 'sub-043', 'sub-044', 'sub-045', 'sub-046', 'sub-048', 'sub-050', 'sub-051', 'sub-052', 'sub-053', 'sub-054', 'sub-055', 'sub-056', 'sub-057', 'sub-058', 'sub-060', 'sub-061', 'sub-062', 'sub-063', 'sub-064', 'sub-065', 'sub-066', 'sub-067', 'sub-068', 'sub-070', 'sub-071', 'sub-072', 'sub-073', 'sub-075', 'sub-076', 'sub-077', 'sub-078', 'sub-079', 'sub-080', 'sub-082', 'sub-083', 'sub-084', 'sub-085', 'sub-086', 'sub-087', 'sub-088', 'sub-089', 'sub-090', 'sub-091', 'sub-092', 'sub-093', 'sub-095', 'sub-096', 'sub-097', 'sub-098', 'sub-099', 'sub-100', 'sub-102', 'sub-103', 'sub-104', 'sub-107', 'sub-109', 'sub-111', 'sub-112', 'sub-114', 'sub-115', 'sub-116', 'sub-117', 'sub-118', 'sub-119', 'sub-120', 'sub-121', 'sub-123', 'sub-124', 'sub-127', 'sub-128', 'sub-129', 'sub-130', 'sub-131', 'sub-132', 'sub-133', 'sub-134', 'sub-135', 'sub-136', 'sub-137', 'sub-138', 'sub-140', 'sub-141', 'sub-142', 'sub-143', 'sub-144', 'sub-145', 'sub-146', 'sub-147', 'sub-148', 'sub-149', 'sub-150', 'sub-151', 'sub-152', 'sub-153', 'sub-154', 'sub-156', 'sub-157', 'sub-159', 'sub-160', 'sub-161', 'sub-162', 'sub-163', 'sub-164', 'sub-166', 'sub-167', 'sub-168', 'sub-169', 'sub-170']
#
#
# [INFO] subjects missing: ['sub-016', 'sub-059', 'sub-074', 'sub-108']

# %%
fmriprep_dict={}

# %%
dataframes=build_fmriprep_report(write_files=False)
# Out:
# [INFO] fmriprep data path: /projects/niblab/experiments/bbx/data/fmriprep/fmriprep_trimmed-20.2.0

# %%
s1_df=dataframes[0]
s1_df.index.name = "patID"
s1_df.drop(remove_subs, inplace=True)
s2_df=dataframes[1] 
s2_df.drop(remove_subs+s2_drop_subjects, inplace=True)
s2_df.index.name = "patID"

# %%
# Get the good data subject rows

s1_filtered_df = s1_df[s1_df.notna().all(axis=1)]
s2_filtered_df = s2_df[s2_df.notna().all(axis=1)]

# %%
len(s1_filtered_df.index.values)
# Out:
# 140

# %%
len(s2_filtered_df.index.values)
# Out:
# 118

# %%
s1_filtered_df.index.values
# Out:
# array(['sub-001', 'sub-002', 'sub-003', 'sub-004', 'sub-005', 'sub-006',
#        'sub-007', 'sub-008', 'sub-009', 'sub-010', 'sub-011', 'sub-012',
#        'sub-013', 'sub-014', 'sub-015', 'sub-017', 'sub-018', 'sub-019',
#        'sub-020', 'sub-021', 'sub-022', 'sub-023', 'sub-024', 'sub-025',
#        'sub-026', 'sub-028', 'sub-030', 'sub-031', 'sub-032', 'sub-033',
#        'sub-034', 'sub-035', 'sub-036', 'sub-037', 'sub-038', 'sub-039',
#        'sub-040', 'sub-041', 'sub-042', 'sub-043', 'sub-044', 'sub-045',
#        'sub-046', 'sub-050', 'sub-051', 'sub-052', 'sub-053', 'sub-054',
#        'sub-055', 'sub-056', 'sub-057', 'sub-058', 'sub-061', 'sub-062',
#        'sub-063', 'sub-064', 'sub-065', 'sub-066', 'sub-067', 'sub-068',
#        'sub-070', 'sub-071', 'sub-072', 'sub-075', 'sub-077', 'sub-078',
#        'sub-079', 'sub-080', 'sub-082', 'sub-083', 'sub-084', 'sub-085',
#        'sub-086', 'sub-087', 'sub-088', 'sub-089', 'sub-090', 'sub-091',
#        'sub-092', 'sub-093', 'sub-095', 'sub-096', 'sub-097', 'sub-098',
#        'sub-099', 'sub-100', 'sub-102', 'sub-103', 'sub-104', 'sub-107',
#        'sub-109', 'sub-111', 'sub-112', 'sub-114', 'sub-115', 'sub-116',
#        'sub-117', 'sub-118', 'sub-119', 'sub-120', 'sub-121', 'sub-123',
#        'sub-124', 'sub-127', 'sub-128', 'sub-129', 'sub-130', 'sub-131',
#        'sub-132', 'sub-133', 'sub-134', 'sub-135', 'sub-136', 'sub-137',
#        'sub-138', 'sub-140', 'sub-141', 'sub-142', 'sub-143', 'sub-144',
#        'sub-145', 'sub-148', 'sub-149', 'sub-150', 'sub-151', 'sub-152',
#        'sub-153', 'sub-154', 'sub-156', 'sub-157', 'sub-160', 'sub-161',
#        'sub-162', 'sub-163', 'sub-164', 'sub-166', 'sub-167', 'sub-168',
#        'sub-169', 'sub-170'], dtype=object)

# %%
s2_filtered_df.index.values
# Out:
# array(['sub-001', 'sub-002', 'sub-004', 'sub-005', 'sub-006', 'sub-007',
#        'sub-008', 'sub-009', 'sub-011', 'sub-013', 'sub-014', 'sub-017',
#        'sub-019', 'sub-022', 'sub-028', 'sub-030', 'sub-031', 'sub-032',
#        'sub-033', 'sub-034', 'sub-036', 'sub-038', 'sub-039', 'sub-040',
#        'sub-041', 'sub-042', 'sub-043', 'sub-045', 'sub-046', 'sub-048',
#        'sub-050', 'sub-051', 'sub-053', 'sub-054', 'sub-055', 'sub-057',
#        'sub-061', 'sub-062', 'sub-063', 'sub-065', 'sub-066', 'sub-067',
#        'sub-068', 'sub-070', 'sub-072', 'sub-073', 'sub-075', 'sub-078',
#        'sub-079', 'sub-080', 'sub-082', 'sub-083', 'sub-084', 'sub-085',
#        'sub-086', 'sub-089', 'sub-090', 'sub-092', 'sub-093', 'sub-095',
#        'sub-096', 'sub-097', 'sub-098', 'sub-099', 'sub-100', 'sub-102',
#        'sub-103', 'sub-104', 'sub-107', 'sub-109', 'sub-111', 'sub-112',
#        'sub-114', 'sub-115', 'sub-116', 'sub-117', 'sub-118', 'sub-119',
#        'sub-120', 'sub-121', 'sub-123', 'sub-124', 'sub-127', 'sub-128',
#        'sub-129', 'sub-130', 'sub-131', 'sub-132', 'sub-133', 'sub-134',
#        'sub-135', 'sub-136', 'sub-137', 'sub-138', 'sub-140', 'sub-141',
#        'sub-142', 'sub-143', 'sub-144', 'sub-145', 'sub-148', 'sub-149',
#        'sub-151', 'sub-152', 'sub-153', 'sub-154', 'sub-156', 'sub-157',
#        'sub-159', 'sub-160', 'sub-161', 'sub-162', 'sub-163', 'sub-164',
#        'sub-166', 'sub-168', 'sub-169', 'sub-170'], dtype=object)

# %% [markdown]
# View the subjects missing in session -2

# %%
[ x for x in list(s1_filtered_df.index.values) if x not in list(s2_filtered_df.index.values)]
# Out:
# ['sub-003',
#  'sub-010',
#  'sub-012',
#  'sub-015',
#  'sub-018',
#  'sub-020',
#  'sub-021',
#  'sub-023',
#  'sub-024',
#  'sub-025',
#  'sub-026',
#  'sub-035',
#  'sub-037',
#  'sub-044',
#  'sub-052',
#  'sub-056',
#  'sub-058',
#  'sub-064',
#  'sub-071',
#  'sub-077',
#  'sub-087',
#  'sub-088',
#  'sub-091',
#  'sub-150',
#  'sub-167']

# %%
#s1_df.style.highlight_null('red')

# %%
#s1_filtered_df

# %%
s2_df.style.highlight_null('red')
# Out:
# <style  type="text/css" >
# #T_4715ecc4_b810_11eb_8c2d_005056a236fcrow8_col7,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow12_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow15_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow17_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col1,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col2,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col3,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col4,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col6,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow18_col7,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow26_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow26_col6,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow33_col7,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow43_col1,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow52_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow64_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col1,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col2,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col3,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col4,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col5,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col6,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow67_col7,#T_4715ecc4_b810_11eb_8c2d_005056a236fcrow111_col5{
#             background-color:  red;
#         }</style><table id="T_4715ecc4_b810_11eb_8c2d_005056a236fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >anat_file_ct</th>        <th class="col_heading level0 col1" >task-training_run-4_vol</th>        <th class="col_heading level0 col2" >task-training_run-3_vol</th>        <th class="col_heading level0 col3" >task-training_run-2_vol</th>        <th class="col_heading level0 col4" >task-training_run-1_vol</th>        <th class="col_heading level0 col5" >task-rl_run-2_vol</th>        <th class="col_heading level0 col6" >task-rl_run-1_vol</th>        <th class="col_heading level0 col7" >task-resting_vol</th>        <th class="col_heading level0 col8" >rl_file_ct</th>        <th class="col_heading level0 col9" >train_file_ct</th>        <th class="col_heading level0 col10" >rest_file_ct</th>    </tr>    <tr>        <th class="index_name level0" >patID</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4715ecc4_b810_11eb_8c2d_005056a236fclevel0_row0" class="row_heading level0 row0" >sub-001</th>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col1" class="data row0 col1" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col2" class="data row0 col2" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col3" class="data row0 col3" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col4" class="data row0 col4" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col5" class="data row0 col5" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col6" class="data row0 col6" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col7" class="data row0 col7" >147</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col8" class="data row0 col8" >2</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col9" class="data row0 col9" >4</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow0_col10" class="data row0 col10" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_4715ecc4_b810_11eb_8c2d_005056a236fclevel0_row1" class="row_heading level0 row1" >sub-002</th>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col1" class="data row1 col1" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col2" class="data row1 col2" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col3" class="data row1 col3" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col4" class="data row1 col4" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col5" class="data row1 col5" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col6" class="data row1 col6" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col7" class="data row1 col7" >147</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col8" class="data row1 col8" >2</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col9" class="data row1 col9" >4</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow1_col10" class="data row1 col10" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_4715ecc4_b810_11eb_8c2d_005056a236fclevel0_row2" class="row_heading level0 row2" >sub-004</th>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col1" class="data row2 col1" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col2" class="data row2 col2" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col3" class="data row2 col3" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col4" class="data row2 col4" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col5" class="data row2 col5" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col6" class="data row2 col6" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col7" class="data row2 col7" >147</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col8" class="data row2 col8" >2</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col9" class="data row2 col9" >4</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow2_col10" class="data row2 col10" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_4715ecc4_b810_11eb_8c2d_005056a236fclevel0_row3" class="row_heading level0 row3" >sub-005</th>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col1" class="data row3 col1" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col2" class="data row3 col2" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col3" class="data row3 col3" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col4" class="data row3 col4" >229</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col5" class="data row3 col5" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col6" class="data row3 col6" >212</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col7" class="data row3 col7" >147</td>
#                         <td id="T_4715ecc4_b810_11eb_8c2d_005056a236fcrow3_col8" clas

# %%
len(s2_df.index.values)
# Out:
# 130

# %%
s2_df[s2_df['task-training_run-2_vol'] == '233']
# Out:
#         anat_file_ct task-training_run-4_vol task-training_run-3_vol  \
# patID
# sub-011            1                     233                     233
# sub-013            1                     233                     233
# sub-138            1                     233                     233
#
#         task-training_run-2_vol task-training_run-1_vol task-rl_run-2_vol  \
# patID
# sub-011                     233                     233               212
# sub-013                     233                     233               212
# sub-138                     233                     233               212
#
#         task-rl_run-1_vol task-resting_vol rl_file_ct train_file_ct  \
# patID
# sub-011               212              147          2             4
# sub-013               212              147          2             4
# sub-138               212              147          2             4
#
#         rest_file_ct
# patID
# sub-011            1
# sub-013            1
# sub-138            1

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Write files

# %%
pathT='/projects/niblab/experiments/bbx/data/quality_analysis/bbx_fmri_data_report.xlsx'

# %%
writer = pd.ExcelWriter(pathT, engine = 'openpyxl')
book = load_workbook(pathT)
writer.book = book
s1_df.to_excel(writer, sheet_name="ses-1_fmriprep")
s2_df.to_excel(writer, sheet_name="ses-2_fmriprep")
writer.save() 
writer.close()

# %%
new_excel=pd.read_excel(pathT, sheet_name="ses-1_fmriprep")

# %%
new_excel.head()
# Out:
#      patID  anat_file_ct  task-training_run-4_vol  task-training_run-3_vol  \
# 0  sub-001             1                    229.0                    229.0
# 1  sub-002             1                    229.0                    229.0
# 2  sub-003             1                    229.0                    229.0
# 3  sub-004             1                    229.0                    229.0
# 4  sub-005             1                    229.0                    229.0
#
#    task-training_run-2_vol  task-training_run-1_vol  task-resting_vol  \
# 0                    229.0                    229.0             147.0
# 1                    229.0                    229.0             147.0
# 2                    229.0                    229.0             147.0
# 3                    229.0                    229.0             147.0
# 4                    229.0                    229.0             147.0
#
#    train_file_ct  rest_file_ct
# 0              4             1
# 1              4             1
# 2              4             1
# 3              4             1
# 4              4             1

# %% [markdown]
# ---

# %%
def display_fmriprep(sub_id=subject_list[0], sess_id=sessions[0]):
    print("[INFO] viewing report for %s"%sub_id)
    fmriprep_path=os.path.join(study_folder_path,'data/fmriprep')
    
    # anat figures
    anat_imgs=glob.glob(os.path.join(fmriprep_path, '%s/figures/*'%sub_id))
    anat_t1w=os.path.join(fmriprep_path, '%s/figures/%s_space-MNI152NLin2009cAsym_T1w.svg'%(sub_id,sub_id))
    try:
        display(SVG(filename=anat_t1w))
        #for svg in anat_imgs:
            #print("[INFO] viewing file %s"%svg)
            #display(SVG(filename=svg))
    except:
        print("[INFO] no anat figures found for %s"%sub_id)

# func figures
    print('\n[INFO] functional reports for %s'%sess_id)
    sess_svgs=glob.glob(os.path.join(fmriprep_path, '%s/%s/figures/*'%(sub_id,sess_id)))
    try:
        for svg in sess_svgs:
            if "flirt" in svg:
            #"brain_mask" in svg or "magnitude_bold" in svg or "rois" in svg or \
            #"flirt" in svg or "sdc" in svg or "fieldmap" in svg:
                print("[INFO] viewing file %s"%svg)
                display(SVG(filename=svg))
    except:
        print("[INFO] no anat figures found for %s"%sub_id)

# %%
# run widget that calls help functions above
w_fmriprep = widgets.Select(options=subject_list)
widgets.interactive(display_fmriprep, sub_id=subject_list, sess_id=sessions)
# Out:
# interactive(children=(Dropdown(description='sub_id', options=('sub-001', 'sub-002', 'sub-003', 'sub-004', 'sub…

# %% [markdown]
# ---

# %% [markdown]
# ---
